# %%
f = open("/Users/rhino/Downloads/DongCode.txt", 'r',encoding='euc-kr')
# line = f.readline()
# print(line)
# lines = f.readlines()
# print(type(lines))

# cnt = 0
# for line in lines:
#     cnt = cnt + 1
    
#     if cnt <= 100:
#         print(line)
    
# data = f.read()
# print("data = ", type(data))   

cnt = 0
for line in f:
    if '수지구 신봉동' in line:
        if '존재' in line:
            print(line[0:10])
    else:
        print("없")

f.close()
# Out:
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# 없
# ...
